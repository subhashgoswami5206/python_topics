# %% [markdown]
# # String indexing and slicing

# %% [markdown]
# # Python index begins with 0 and ends with n-1
#     1. Forward Indexing -  left to right | ( begins with 0 )
#     2. Backward Indexing - right to left | ( begins with -1 )
#     3. Step Indexing
