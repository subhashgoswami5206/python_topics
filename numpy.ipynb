# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.4.2'

# %%
mylist = [1,2,3,4,5]
mylist
# Out:
# [1, 2, 3, 4, 5]

# %%
arr = np.array(mylist)
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.ndarray(shape=(5), dtype=int, buffer=np.array([1,2,3,4,5]))
# Out:
# array([1, 2, 3, 4, 5])
