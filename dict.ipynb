# %% [markdown]
# # Dict

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d1 = {"name":"FSDS", "course":"AI", "duration":"6 months"}

# %%
d1.keys()
# Out:
# dict_keys(['name', 'course', 'duration'])

# %%
d1.values()
# Out:
# dict_values(['FSDS', 'AI', '6 months'])

# %%
d1.items()
# Out:
# dict_items([('name', 'FSDS'), ('course', 'AI'), ('duration', '6 months')])

# %%
d1["name"]
# Out:
# 'FSDS'

# %%
d2=d1.copy()

# %%
d1 == d2
# Out:
# True

# %%
print(d1)
print(d2)
# Out:
# {'name': 'FSDS', 'course': 'AI', 'duration': '6 months'}
# {'name': 'FSDS', 'course': 'AI', 'duration': '6 months'}

# %%
list.count(list(d1.items()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 list.count(list(d1.items()))
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
mydict = {1: 'one',2:'two', 'A': {'B': 'C', 'D': 'E'}, 'B':(1,2,3), 'C': [1,2,3]}
mydict
# Out:
# {1: 'one', 2: 'two', 'A': {'B': 'C', 'D': 'E'}, 'B': (1, 2, 3), 'C': [1, 2, 3]}

# %%
keys = ['a', 'b', 'c', 'd']
values = [1, 2, 3, 4]
mydict3 = dict.fromkeys(keys, values)

# %%
mydict3
# Out:
# {'a': [1, 2, 3, 4], 'b': [1, 2, 3, 4], 'c': [1, 2, 3, 4], 'd': [1, 2, 3, 4]}

# %%
values.append(5)

# %%
mydict3
# Out:
# {'a': [1, 2, 3, 4, 5],
#  'b': [1, 2, 3, 4, 5],
#  'c': [1, 2, 3, 4, 5],
#  'd': [1, 2, 3, 4, 5]}

# %%
mydict3[a]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 mydict3[a]
#
# NameError: name 'a' is not defined

# %%
mydict3.get('a')
# Out:
# [1, 2, 3, 4, 5]

# %%
d1=mydict3

# %%
d1["10"]="ten"
d1
# Out:
# {'a': [1, 2, 3, 4, 5],
#  'b': [1, 2, 3, 4, 5],
#  'c': [1, 2, 3, 4, 5],
#  'd': [1, 2, 3, 4, 5],
#  '10': 'ten'}

# %%
d1.pop("10",'ten')
# Out:
# 'ten'

# %%
d1.popitem("10")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 d1.popitem("10")
#
# TypeError: dict.popitem() takes no arguments (1 given)

# %%
d1.popitem()
# Out:
# ('c', [1, 2, 3, 4, 5])

# %%
d1.popitem()
# Out:
# ('b', [1, 2, 3, 4, 5])

# %%
d1
# Out:
# {'a': [1, 2, 3, 4, 5]}
