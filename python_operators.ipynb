# %% [markdown]
# # Python opeartors

# %% [markdown]
# 1. Arithmetic Operator -  + , - , * , / , // , % , **
# 2. Assignment Operator -  = , += , -= , *= , /= , //=
# 3. Relational Operator -  < , >, = , >= , <= , == , !=
# 4. Unary Operator      -  Unary means only 1
# 5. Logical Operator    -  Truth table ( AND OR NOT)

# %% [markdown]
# # Arithmetic Operator

# %%
x1 , y1 = 10,5

# %%
x1 + y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1 * y1
# Out:
# 50

# %%
x1 ** y1
# Out:
# 100000

# %%
x1 % y1
# Out:
# 0

# %%
x1 / y1
# Out:
# 2.0

# %%
x1 // y1
# Out:
# 2

# %% [markdown]
# # Assignment Operator

# %%
x = 2

# %%
x = x+2
x
# Out:
# 4

# %%
x += 2
x
# Out:
# 6

# %%
x -= 2
x
# Out:
# 4

# %%
x = 6
x /= 2
x
# Out:
# 3.0

# %%
x = 6
x //= 2
x
# Out:
# 3

# %%
x=4
x *= 2
x
# Out:
# 8

# %% [markdown]
# # Unary Operator

# %% [markdown]
#  Unary Operator means only 1   like binary means 2

# %%
n = 7
n
# Out:
# 7

# %%
m = -(n)
m
# Out:
# -7

# %% [markdown]
# # Logical Operator    -  Truth table ( AND OR NOT)

# %% [markdown]
# In AND =>  1 AND 1 = 1 , rest of them is 0
# In OR =>   0 AND 0 =0 , rest of them is 1

# %%
x,y = 6,7
x > 5 and y < 8
# Out:
# True

# %%
x = False

# %%
not x
# Out:
# True

# %%
x
# Out:
# False

# %%
not x
# Out:
# True
